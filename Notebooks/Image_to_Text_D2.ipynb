# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.layers import TextVectorization
seed = 111
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Path to the images
PATH = "../Data/D2/"

# Desired image dimensions
IMAGE_SIZE = (512, 512)

# Vocabulary size
VOCAB_SIZE = 500


# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters
BATCH_SIZE = 32
EPOCHS = 30
AUTOTUNE = tf.data.AUTOTUNE

# %%
def load_captions_data():
    """Loads captions (text) data and maps them to corresponding images.

    Args:
        filename: Path to the text file containing caption data.

    Returns:
        caption_mapping: Dictionary mapping image names and the corresponding captions
        text_data: List containing all the available captions
    """
    import os
    # for file as os.listdir(PATH+'TEXT_LABELS'):
    #     caption_data = caption_file.readlines()
    caption_mapping = {}
    text_data = []
        # images_to_skip = set()
    for filename in os.listdir(PATH+'TEXT_LABELS/'):
    
        with open(PATH+'TEXT_LABELS/'+filename) as file:
            file_data = file.readlines()
            line = " ".join(file_data)
            line = line.replace("\n"," <NEWLINE>")
            line = line.replace("{","<BRACES>")
            line = line.replace("}","<BRACEE>")
            # words = line.split(' ')
            # Image name and captions are separated using a tab
            img_name, caption = filename, line

            # Each image is repeated five times for the five different captions.
            # Each image name has a suffix `#(caption_number)`
            # img_name = img_name.split("#")[0]
            img_name = os.path.join(PATH+'IMAGES/', img_name.strip()[:-3]+'png')

            # We will remove caption that are either too short to too long
            # tokens = words

            # if len(tokens) < 5 or len(tokens) > SEQ_LENGTH:
            #     images_to_skip.add(img_name)
            #     continue

            # if img_name.endswith("jpg") and img_name not in images_to_skip:
            #     # We will add a start and an end token to each caption
            caption = "<start> " + caption.strip() + " <end>"
            text_data.append(caption)

            if img_name in caption_mapping:
                caption_mapping[img_name].append(caption)
            else:
                caption_mapping[img_name] = [caption]

        # for img_name in images_to_skip:
        #   if img_name in caption_mapping:
        #       del caption_mapping[img_name]

    return caption_mapping, text_data


def train_val_split(caption_data, train_size=0.8, shuffle=True):
    """Split the captioning dataset into train and validation sets.

    Args:
        caption_data (dict): Dictionary containing the mapped caption data
        train_size (float): Fraction of all the full dataset to use as training data
        shuffle (bool): Whether to shuffle the dataset before splitting

    Returns:
        Traning and validation datasets as two separated dicts
    """

    # 1. Get the list of all image names
    all_images = list(caption_data.keys())

    # 2. Shuffle if necessary
    if shuffle:
        np.random.shuffle(all_images)

    # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_size)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size:]
    }

    # 4. Return the splits
    return training_data, validation_data


# Load the dataset
captions_mapping, text_data = load_captions_data()

# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  240
# Number of validation samples:  60

# %%
# Fixed length allowed for any sequence
SEQ_LENGTH = max([len(x.split()) for x in text_data]) + 50

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    # return lowercase
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")


vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)
# Out:
# 2022-08-10 10:08:14.365404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.392190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.392395: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.393371: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-10 10:08:14.394122: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.394259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.394370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.747036: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.747188: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.747297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-10 10:08:14.747394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3673 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
vectorization.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  '<newline>',
#  '<braces>',
#  '<bracee>',
#  'text',
#  'smalltitle',
#  'btninactive',
#  'quadruple',
#  'row',
#  'btnred',
#  'btngreen',
#  'btnorange',
#  'sidebar',
#  'header',
#  'canvasheader',
#  '<start>',
#  '<end>',
#  'btnactive',
#  'double',
#  'searchbar',
#  'radio',
#  'mediumtitle',
#  'icons',
#  'burgerlink',
#  'cartlink',
#  'ckbox',
#  'rating',
#  'dropdn',
#  'slider',
#  'pagetitle',
#  'single']

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(len(images))
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset

# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

# %%
train_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 161), dtype=tf.int64, name=None))>

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(
        input_shape=(*IMAGE_SIZE, 3), include_top=False, weights="imagenet",
    )
    # We freeze our feature extractor
    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model


class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM, sequence_length=SEQ_LENGTH, vocab_size=VOCAB_SIZE
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)


class ImageCaptioningModel(keras.Model):
    def __init__(
        self, cnn_model, encoder, decoder, num_captions_per_image=1, image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                # 3. Update loss and accuracy
                batch_loss += loss
                batch_acc += acc

            # 4. Get the list of all the trainable weights
            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            # 5. Get the gradients
            grads = tape.gradient(loss, train_vars)

            # 6. Update the trainable weights
            self.optimizer.apply_gradients(zip(grads, train_vars))

        # 7. Update the trackers
        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 8. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        # 1. Get image embeddings
        img_embed = self.cnn_model(batch_img)

        # 2. Pass each of the five captions one by one to the decoder
        # along with the encoder outputs and compute the loss as well as accuracy
        # for each caption.
        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            # 3. Update batch loss and batch accuracy
            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)

        # 4. Update the trackers
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        # 5. Return the loss and accuracy values
        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker, self.acc_tracker]


cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model, encoder=encoder, decoder=decoder, image_aug=image_augmentation,
)

# %%
# Define the loss function
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="none"
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)


# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.Adam(lr_schedule), loss=cross_entropy)

# Fit the model
caption_model.fit(
    train_dataset,
    epochs=100,
    validation_data=valid_dataset,
    callbacks=[early_stopping],verbose=True)
# Out:
# Epoch 1/100
# 2022-08-10 10:08:21.052789: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-08-10 10:08:21.077772: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-08-10 10:08:22.180817: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-08-10 10:08:22.427358: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-08-10 10:08:22.427458: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 8/8 [==============================] - 13s 833ms/step - loss: 7.1372 - acc: 0.0014 - val_loss: 5.6515 - val_acc: 0.1468
# Epoch 2/100
# 8/8 [==============================] - 3s 386ms/step - loss: 4.8585 - acc: 0.1178 - val_loss: 3.1757 - val_acc: 0.3500
# Epoch 3/100
# 8/8 [==============================] - 3s 402ms/step - loss: 2.9245 - acc: 0.4128 - val_loss: 2.0383 - val_acc: 0.5976
# Epoch 4/100
# 8/8 [==============================] - 3s 389ms/step - loss: 2.2036 - acc: 0.5098 - val_loss: 1.5459 - val_acc: 0.6224
# Epoch 5/100
# 8/8 [==============================] - 3s 393ms/step - loss: 1.7512 - acc: 0.5854 - val_loss: 1.2854 - val_acc: 0.6643
# Epoch 6/100
# 8/8 [==============================] - 3s 392ms/step - loss: 1.4932 - acc: 0.6353 - val_loss: 1.1086 - val_acc: 0.6701
# Epoch 7/100
# 8/8 [==============================] - 3s 394ms/step - loss: 1.3176 - acc: 0.6372 - val_loss: 0.9988 - val_acc: 0.6856
# Epoch 8/100
# 8/8 [==============================] - 3s 408ms/step - loss: 1.1918 - acc: 0.6546 - val_loss: 0.8936 - val_acc: 0.6907
# Epoch 9/100
# 8/8 [==============================] - 3s 376ms/step - loss: 1.0948 - acc: 0.6591 - val_loss: 0.8204 - val_acc: 0.7098
# Epoch 10/100
# 8/8 [==============================] - 3s 408ms/step - loss: 1.0002 - acc: 0.6693 - val_loss: 0.7488 - val_acc: 0.7384
# Epoch 11/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.9225 - acc: 0.6818 - val_loss: 0.6971 - val_acc: 0.7457
# Epoch 12/100
# 8/8 [==============================] - 3s 364ms/step - loss: 0.8625 - acc: 0.6982 - val_loss: 0.6526 - val_acc: 0.7627
# Epoch 13/100
# 8/8 [==============================] - 3s 367ms/step - loss: 0.8075 - acc: 0.7152 - val_loss: 0.6018 - val_acc: 0.7845
# Epoch 14/100
# 8/8 [==============================] - 3s 376ms/step - loss: 0.7682 - acc: 0.7215 - val_loss: 0.5705 - val_acc: 0.8000
# Epoch 15/100
# 8/8 [==============================] - 3s 373ms/step - loss: 0.7220 - acc: 0.7325 - val_loss: 0.5460 - val_acc: 0.7954
# Epoch 16/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.6831 - acc: 0.7481 - val_loss: 0.5062 - val_acc: 0.8134
# Epoch 17/100
# 8/8 [==============================] - 3s 366ms/step - loss: 0.6616 - acc: 0.7562 - val_loss: 0.5170 - val_acc: 0.7934
# Epoch 18/100
# 8/8 [==============================] - 3s 372ms/step - loss: 0.6397 - acc: 0.7546 - val_loss: 0.4786 - val_acc: 0.8136
# Epoch 19/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.6258 - acc: 0.7612 - val_loss: 0.4610 - val_acc: 0.8255
# Epoch 20/100
# 8/8 [==============================] - 3s 402ms/step - loss: 0.6033 - acc: 0.7727 - val_loss: 0.4510 - val_acc: 0.8250
# Epoch 21/100
# 8/8 [==============================] - 4s 483ms/step - loss: 0.5920 - acc: 0.7749 - val_loss: 0.4674 - val_acc: 0.8071
# Epoch 22/100
# 8/8 [==============================] - 3s 398ms/step - loss: 0.5985 - acc: 0.7748 - val_loss: 0.4408 - val_acc: 0.8332
# Epoch 23/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.5847 - acc: 0.7742 - val_loss: 0.4345 - val_acc: 0.8353
# Epoch 24/100
# 8/8 [==============================] - 3s 393ms/step - loss: 0.5616 - acc: 0.7834 - val_loss: 0.4076 - val_acc: 0.8361
# Epoch 25/100
# 8/8 [==============================] - 3s 397ms/step - loss: 0.5604 - acc: 0.7836 - val_loss: 0.4032 - val_acc: 0.8374
# Epoch 26/100
# 8/8 [==============================] - 3s 387ms/step - loss: 0.5451 - acc: 0.7867 - val_loss: 0.4028 - val_acc: 0.8380
# Epoch 27/100
# 8/8 [==============================] - 3s 376ms/step - loss: 0.5331 - acc: 0.7929 - val_loss: 0.4050 - val_acc: 0.8287
# Epoch 28/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.5337 - acc: 0.7874 - val_loss: 0.3791 - val_acc: 0.8530
# Epoch 29/100
# 8/8 [==============================] - 3s 370ms/step - loss: 0.5261 - acc: 0.7948 - val_loss: 0.3665 - val_acc: 0.8522
# Epoch 30/100
# 8/8 [==============================] - 3s 363ms/step - loss: 0.5063 - acc: 0.7997 - val_loss: 0.3886 - val_acc: 0.8274
# Epoch 31/100
# 8/8 [==============================] - 3s 375ms/step - loss: 0.5053 - acc: 0.8051 - val_loss: 0.3469 - val_acc: 0.8577
# Epoch 32/100
# 8/8 [==============================] - 3s 390ms/step - loss: 0.4978 - acc: 0.8045 - val_loss: 0.3397 - val_acc: 0.8754
# Epoch 33/100
# 8/8 [==============================] - 3s 376ms/step - loss: 0.4904 - acc: 0.8045 - val_loss: 0.3821 - val_acc: 0.8312
# Epoch 34/100
# 8/8 [==============================] - 3s 377ms/step - loss: 0.4945 - acc: 0.8028 - val_loss: 0.3368 - val_acc: 0.8572
# Epoch 35/100
# 8/8 [==============================] - 3s 378ms/step - loss: 0.4764 - acc: 0.8125 - val_loss: 0.3251 - val_acc: 0.8796
# Epoch 36/100
# 8/8 [==============================] - 3s 408ms/step - loss: 0.4728 - acc: 0.8123 - val_loss: 0.3214 - val_acc: 0.8648
# Epoch 37/100
# 8/8 [==============================] - 3s 412ms/step - loss: 0.4587 - acc: 0.8173 - val_loss: 0.3382 - val_acc: 0.8523
# Epoch 38/100
# 8/8 [==============================] - 3s 416ms/step - loss: 0.4497 - acc: 0.8168 - val_loss: 0.3011 - val_acc: 0.8774
# Epoch 39/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.4488 - acc: 0.8186 - val_loss: 0.2917 - val_acc: 0.8841
# Epoch 40/100
# 8/8 [==============================] - 3s 387ms/step - loss: 0.4299 - acc: 0.8290 - val_loss: 0.2853 - val_acc: 0.8826
# Epoch 41/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.4286 - acc: 0.8272 - val_loss: 0.2925 - val_acc: 0.8817
# Epoch 42/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.4230 - acc: 0.8313 - val_loss: 0.2970 - val_acc: 0.8675
# Epoch 43/100
# 8/8 [==============================] - 3s 376ms/step - loss: 0.4218 - acc: 0.8352 - val_loss: 0.2800 - val_acc: 0.8753
# Epoch 44/100
# 8/8 [==============================] - 3s 368ms/step - loss: 0.4153 - acc: 0.8285 - val_loss: 0.2814 - val_acc: 0.8754
# Epoch 45/100
# 8/8 [==============================] - 3s 377ms/step - loss: 0.3952 - acc: 0.8355 - val_loss: 0.2677 - val_acc: 0.8794
# Epoch 46/100
# 8/8 [==============================] - 3s 374ms/step - loss: 0.3942 - acc: 0.8429 - val_loss: 0.2607 - val_acc: 0.8881
# Epoch 47/100
# 8/8 [==============================] - 3s 372ms/step - loss: 0.3858 - acc: 0.8430 - val_loss: 0.2586 - val_acc: 0.8829
# Epoch 48/100
# 8/8 [==============================] - 3s 370ms/step - loss: 0.3803 - acc: 0.8448 - val_loss: 0.2443 - val_acc: 0.8978
# Epoch 49/100
# 8/8 [==============================] - 3s 365ms/step - loss: 0.3791 - acc: 0.8472 - val_loss: 0.2504 - val_acc: 0.8891
# Epoch 50/100
# 8/8 [==============================] - 3s 371ms/step - loss: 0.3684 - acc: 0.8511 - val_loss: 0.2412 - val_acc: 0.8960
# Epoch 51/100
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3568 - acc: 0.8554 - val_loss: 0.2306 - val_acc: 0.9023
# Epoch 52/100
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3405 - acc: 0.8599 - val_loss: 0.2223 - val_acc: 0.9073
# Epoch 53/100
# 8/8 [==============================] - 3s 373ms/step - loss: 0.3411 - acc: 0.8593 - val_loss: 0.2180 - val_acc: 0.9101
# Epoch 54/100
# 8/8 [==============================] - 3s 369ms/step - loss: 0.3316 - acc: 0.8629 - val_loss: 0.2160 - val_acc: 0.9085
# Epoch 55/100
# 8/8 [==============================] - 3s 369ms/step - loss: 0.3360 - acc: 0.8709 - val_loss: 0.2218 - val_acc: 0.9072
# Epoch 56/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.3310 - acc: 0.8660 - val_loss: 0.2156 - val_acc: 0.9027
# Epoch 57/100
# 8/8 [==============================] - 3s 392ms/step - loss: 0.3177 - acc: 0.8726 - val_loss: 0.1920 - val_acc: 0.9191
# Epoch 58/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.3070 - acc: 0.8764 - val_loss: 0.1802 - val_acc: 0.9306
# Epoch 59/100
# 8/8 [==============================] - 3s 344ms/step - loss: 0.2957 - acc: 0.8814 - val_loss: 0.1829 - val_acc: 0.9310
# Epoch 60/100
# 8/8 [==============================] - 3s 355ms/step - loss: 0.2905 - acc: 0.8876 - val_loss: 0.1670 - val_acc: 0.9373
# Epoch 61/100
# 8/8 [==============================] - 3s 354ms/step - loss: 0.2820 - acc: 0.8881 - val_loss: 0.1654 - val_acc: 0.9382
# Epoch 62/100
# 8/8 [==============================] - 3s 343ms/step - loss: 0.2777 - acc: 0.8856 - val_loss: 0.1790 - val_acc: 0.9336
# Epoch 63/100
# 8/8 [==============================] - 3s 349ms/step - loss: 0.2838 - acc: 0.8869 - val_loss: 0.1628 - val_acc: 0.9349
# Epoch 64/100
# 8/8 [==============================] - 3s 342ms/step - loss: 0.2680 - acc: 0.8957 - val_loss: 0.1665 - val_acc: 0.9333
# Epoch 65/100
# 8/8 [==============================] - 3s 352ms/step - loss: 0.2623 - acc: 0.8948 - val_loss: 0.1487 - val_acc: 0.9419
# Epoch 66/100
# 8/8 [==============================] - 3s 342ms/step - loss: 0.2686 - acc: 0.8961 - val_loss: 0.1561 - val_acc: 0.9407
# Epoch 67/100
# 8/8 [==============================] - 3s 342ms/step - loss: 0.2584 - acc: 0.8972 - val_loss: 0.1529 - val_acc: 0.9357
# Epoch 68/100
# 8/8 [==============================] - 3s 354ms/step - loss: 0.2524 - acc: 0.9024 - val_loss: 0.1465 - val_acc: 0.9449
# Epoch 69/100
# 8/8 [==============================] - 3s 342ms/step - loss: 0.2465 - acc: 0.9024 - val_loss: 0.1486 - val_acc: 0.9401
# Epoch 70/100
# 8/8 [==============================] - 3s 351ms/step - loss: 0.2497 - acc: 0.9009 - val_loss: 0.1384 - val_acc: 0.9485
# Epoch 71/100
# 8/8 [==============================] - 3s 349ms/step - loss: 0.2436 - acc: 0.9042 - val_loss: 0.1326 - val_acc: 0.9507
# Epoch 72/100
# 8/8 [==============================] - 3s 351ms/step - loss: 0.2297 - acc: 0.9077 - val_loss: 0.1309 - val_acc: 0.9487
# Epoch 73/100
# 8/8 [==============================] - 3s 343ms/step - loss: 0.2247 - acc: 0.9123 - val_loss: 0.1354 - val_acc: 0.9461
# Epoch 74/100
# 8/8 [==============================] - 3s 348ms/step - loss: 0.2294 - acc: 0.9112 - val_loss: 0.1359 - val_acc: 0.9472
# Epoch 75/100
# 8/8 [==============================] - 3s 380ms/step - loss: 0.2236 - acc: 0.9087 - val_loss: 0.1386 - val_acc: 0.9441

# %%
caption_model.save_weights("../models/D2_weights")
print('Model Saved!')
# Out:
# Model Saved!

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == "<end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "")
    decoded_caption = decoded_caption.replace("<newline>", "\n")
    decoded_caption = decoded_caption.replace("<braces>", "{")
    decoded_caption = decoded_caption.replace("<bracee>", "}").strip()
    print("Predicted Caption: ", decoded_caption)


# Check predictions for a few samples
generate_caption()
generate_caption()
generate_caption()
# Out:
# Predicted Caption:  header {
#  pagetitle searchbar
#  }
#  sidebar {
#  mediumtitle radio slider rating
#  }
#  canvasheader {
#  btninactive btninactive btninactive btnactive btninactive
#  }
#  row {
#  single {
#  smalltitle text btnred
#  }
#  }
# Predicted Caption:  header {
#  searchbar cartlink
#  }
#  sidebar {
#  radio icons
#  }
#  canvasheader {
#  btninactive btninactive btninactive btnactive
#  }
#  row {
#  quadruple {
#  smalltitle text btngreen
#  }
#  quadruple {
#  smalltitle text btngreen
#  }
#  quadruple {
#  smalltitle text btngreen
#  }
#  }
#  quadruple {
#  smalltitle text btngreen
#  }
#  }
#  row {
#  double {
#  smalltitle text btngreen
#  }
#  double {
#  smalltitle text btngreen
#  }
#  }
# Predicted Caption:  header {
#  cartlink
#  }
#  sidebar {
#  mediumtitle ckbox radio icons
#  }
#  canvasheader {
#  btninactive btninactive btnactive
#  }
#  row {
#  single {
#  smalltitle text btnred
#  }
#  }

# %%
text_data
# Out:
# ['<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, dropdn, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, dropdn, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, dropdn, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, dropdn, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, dropdn, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> dropdn, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, dropdn <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, dropdn <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> dropdn, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, dropdn, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, dropdn, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, dropdn, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, dropdn, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, dropdn, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, dropdn, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
# ...
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, dropdn <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, dropdn, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, dropdn, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, dropdn, slider, rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, radio, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, dropdn, slider, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-inactive, btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> radio, dropdn, slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> single <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> rating, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> dropdn, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, radio, rating <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-orange <NEWLINE> <BRACEE> <NEWLINE> quadruple <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, search-bar, cart-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> slider, icons <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> medium-title, ck-box, dropdn, slider <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-active, btn-inactive, btn-inactive, btn-inactive, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> <end>',
#  '<start> header <BRACES> <NEWLINE> page-title, cart-link, burger-link <NEWLINE> <BRACEE> <NEWLINE> sidebar <BRACES> <NEWLINE> ck-box, radio, dropdn <NEWLINE> <BRACEE> <NEWLINE> canvas-header <BRACES> <NEWLINE> btn-inactive, btn-active, btn-inactive <NEWLINE> <BRACEE> <NEWLINE> row <BRACES> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-red <NEWLINE> <BRACEE> <NEWLINE> double <BRACES> <NEWLINE> small-title, text, btn-green <NEWLINE> <BRACEE> <NEWLINE> <BRACEE> <NEWLINE> <end>']
